# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\manpr\OneDrive\Desktop\archive\US_Accidents_Dec21_updated.csv")

# %%
df.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
df.shape
# Out:
# (2845342, 47)

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
df.isna().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1743911
# Street                         2
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1319
# Country                        0
# Timezone                    3659
# Airport_Code                9549
# Weather_Timestamp          50736
# Temperature(F)             69274
# Wind_Chill(F)             469643
# Humidity(%)                73092
# Pressure(in)               59200
# Visibility(mi)             70546
# Wind_Direction             73775
# Wind_Speed(mph)           157944
# ...

# %%
missing= df.isna().sum().sort_values(ascending = True)
missing = missing.to_frame()
missing.columns=['missing_count']
missing[missing["missing_count"]>0]
# Out:
#                        missing_count
# Street                             2
# City                             137
# Zipcode                         1319
# Civil_Twilight                  2867
# Sunrise_Sunset                  2867
# Astronomical_Twilight           2867
# Nautical_Twilight               2867
# Timezone                        3659
# Airport_Code                    9549
# Weather_Timestamp              50736
# Pressure(in)                   59200
# Temperature(F)                 69274
# Visibility(mi)                 70546
# Weather_Condition              70636
# Humidity(%)                    73092
# Wind_Direction                 73775
# Wind_Speed(mph)               157944
# Wind_Chill(F)                 469643
# Precipitation(in)             549458
# Number                       1743911

# %%
cities=df['City'].unique()
len(cities)
# Out:
# 11682

# %% [markdown]
# # Top 10 Cities with most number of accidents

# %%
cities_by_accident=df['City'].value_counts()
cities_by_accident
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
cities_by_accident.head(20)
# Out:
# Miami           106966
# Los Angeles      68956
# Orlando          54691
# Dallas           41979
# Houston          39448
# Charlotte        33152
# Sacramento       32559
# San Diego        26627
# Raleigh          22840
# Minneapolis      22768
# Portland         20944
# Nashville        20267
# Austin           18301
# Baton Rouge      18182
# Phoenix          17143
# Saint Paul       16869
# New Orleans      16251
# Atlanta          15622
# Jacksonville     14967
# Richmond         14349
# Name: City, dtype: int64

# %%
'New York' in df.City
# Out:
# False

# %%
'NY' in df.State
# Out:
# False

# %%
fig, ax = plt.subplots(figsize=(5,5))
cities_by_accident.head(10).plot(kind='bar')
ax.set(title = 'Top 10 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
plt.show()

# %%
import seaborn as sns
sns.distplot(cities_by_accident)
# Out:
# C:\Users\manpr\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
high_accident_cities= cities_by_accident[cities_by_accident>=1000]
low_accident_cities = cities_by_accident[cities_by_accident<1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.04245848313644924

# %%
high_accident_cities.plot(kind='hist',bins=1000,logx=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
low_accident_cities.plot(kind='hist',bins=1000,logx=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# Carney                          1
# Waverly Hall                    1
# Center Sandwich                 1
# Glen Flora                      1
# Sulphur Springs                 1
#                                ..
# Ridgedale                       1
# Sekiu                           1
# Wooldridge                      1
# Bullock                         1
# American Fork-Pleasant Grove    1
# Name: City, Length: 1110, dtype: int64

# %%
df.Start_Time[0]
# Out:
# '2016-02-08 00:37:08'

# %%
### Need to change data type of Start_time
df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
### Succesfully changed datatype of Start_Time column 
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 00:37:08')

# %%
df.Start_time = pd.to_datetime(df.Start_Time)
# Out:
# C:\Users\manpr\AppData\Local\Temp\ipykernel_5956\2365298395.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.Start_time = pd.to_datetime(df.Start_Time)

# %%
a=sns.histplot(df.Start_Time.dt.hour,bins=24)
a.set(xlabel='Hour',
     ylabel='No. of accidents')
# Out:
# [Text(0.5, 0, 'Hour'), Text(0, 0.5, 'No. of accidents')]

# %%
a=sns.histplot(df.Start_Time.dt.dayofweek,bins=7)
a.set(xlabel='Days of week',
     ylabel='No. of accidents')
# Out:
# [Text(0.5, 0, 'Days of week'), Text(0, 0.5, 'No. of accidents')]

# %%
Weekend = sns.histplot(df.Start_Time.dt.hour[(df.Start_Time.dt.dayofweek == 5 )|(df.Start_Time.dt.dayofweek == 6) ],bins =24)
Weekend.set(xlabel ='Hour',
           ylabel = 'No. of Accidents',
           title = 'Accidents During Weekends')
# Out:
# [Text(0.5, 0, 'Hour'),
#  Text(0, 0.5, 'No. of Accidents'),
#  Text(0.5, 1.0, 'Accidents During Weekends')]

# %%
# Accidents by order of severity (1 being lowest, and 4 being highest)
accidents_severity = df.groupby('Severity').count()['ID']
accidents_severity
# Out:
# Severity
# 1      26053
# 2    2532991
# 3     155105
# 4     131193
# Name: ID, dtype: int64

# %%
a=accidents_severity.plot(kind='pie',autopct = '%1.1f%%')
a.set(title='Accidents by Severity')
# Out:
# [Text(0.5, 1.0, 'Accidents by Severity')]

# %%
Saturday = df[df.Start_Time.dt.dayofweek == 5]
Sunday = df[df.Start_Time.dt.dayofweek == 6]

# %%
Saturday_Accident=sns.histplot(Saturday['Start_Time'].dt.hour,bins=24)
Saturday_Accident.set(xlabel ='Hour',
           ylabel = 'No. of Accidents',
           title = 'Accidents During Saturday')
# Out:
# [Text(0.5, 0, 'Hour'),
#  Text(0, 0.5, 'No. of Accidents'),
#  Text(0.5, 1.0, 'Accidents During Saturday')]

# %%
Sunday_Accident=sns.histplot(Sunday['Start_Time'].dt.hour,bins=24)
Sunday_Accident.set(xlabel ='Hour',
           ylabel = 'No. of Accidents',
           title = 'Accidents During Sunday')
plt.show()

# %%
Yearly = sns.histplot(df['Start_Time'].dt.month, bins = 12)
Yearly.set(xlabel='Month',
          ylabel='Accident Occurance',
          title = 'Accidents Occurence by Month of the Year')



plt.show()

# %%
dt_2016 = df[df.Start_Time.dt.year == 2016]
dt_2017 = df[df.Start_Time.dt.year == 2017]
dt_2018 = df[df.Start_Time.dt.year == 2018]
dt_2019 = df[df.Start_Time.dt.year == 2019]
dt_2020 = df[df.Start_Time.dt.year == 2020]
dt_2021 = df[df.Start_Time.dt.year == 2021]

# %%
y_2016 = sns.histplot(dt_2016['Start_Time'].dt.month, bins = 12)
y_2016.set(xlabel='Month',
          ylabel='Accident Occurance',
          title = 'Accidents Occurence by Month of the Year 2016')
plt.show()

# %%
y_2017 = sns.histplot(dt_2017['Start_Time'].dt.month, bins = 12)
y_2017.set(xlabel='Month',
          ylabel='Accident Occurance',
          title = 'Accidents Occurence by Month of the Year 2017')
plt.show()

# %%
y_2018 = sns.histplot(dt_2018['Start_Time'].dt.month, bins = 12)
y_2018.set(xlabel='Month',
          ylabel='Accident Occurance',
          title = 'Accidents Occurence by Month of the Year 2018')
plt.show()

# %%
y_2019 = sns.histplot(dt_2019['Start_Time'].dt.month, bins = 12)
y_2019.set(xlabel='Month',
          ylabel='Accident Occurance',
          title = 'Accidents Occurence by Month of the Year 2019')
plt.show()

# %%
y_2020 = sns.histplot(dt_2020['Start_Time'].dt.month, bins = 12)
y_2020.set(xlabel='Month',
          ylabel='Accident Occurance',
          title = 'Accidents Occurence by Month of the Year 2020')
plt.show()

# %%
y_2021 = sns.histplot(dt_2021['Start_Time'].dt.month, bins = 12)
y_2021.set(xlabel='Month',
          ylabel='Accident Occurance',
          title = 'Accidents Occurence by Month of the Year 2021')
plt.show()

# %% [markdown]
#  Data for 2017,2018 seems more balanced, while there were missing data in 2016 and 2020 (2016 start of data collection so system might not have been fully in place).

# %%
side_of_road = df.groupby(['Side']).count()['ID']
side_of_road
# Out:
# Side
# L     492032
# N          1
# R    2353309
# Name: ID, dtype: int64

# %%
label=["Left" , "Right"]
side = side_of_road.plot(kind='pie',autopct='%1.1f%%' )
side.set(title = 'Accidents Occurence om Side of Road')
plt.show()

# %%
weather_conditions = df.groupby(['Weather_Condition']).count()['ID']
weather_conditions
# Out:
# Weather_Condition
# Blowing Dust                142
# Blowing Dust / Windy        148
# Blowing Sand                  1
# Blowing Snow                162
# Blowing Snow / Windy         86
#                            ...
# Volcanic Ash                  4
# Widespread Dust              50
# Widespread Dust / Windy      18
# Wintry Mix                 3843
# Wintry Mix / Windy           74
# Name: ID, Length: 127, dtype: int64

# %%
weather_conditions.sort_values(ascending=False)
# Out:
# Weather_Condition
# Fair                         1107194
# Mostly Cloudy                 363959
# Cloudy                        348767
# Partly Cloudy                 249939
# Clear                         173823
#                               ...
# Low Drifting Snow                  1
# Light Fog                          1
# Mist / Windy                       1
# Sand / Dust Whirls Nearby          1
# Sleet / Windy                      1
# Name: ID, Length: 127, dtype: int64

# %%
weather_conditions.sort_values(ascending=False).head(20)
# Out:
# Weather_Condition
# Fair                       1107194
# Mostly Cloudy               363959
# Cloudy                      348767
# Partly Cloudy               249939
# Clear                       173823
# Light Rain                  128403
# Overcast                     84882
# Scattered Clouds             45132
# Light Snow                   43752
# Fog                          41226
# Haze                         36354
# Rain                         31044
# Fair / Windy                 15195
# Heavy Rain                   11824
# Smoke                         7200
# Light Drizzle                 7041
# Thunder in the Vicinity       6944
# Cloudy / Windy                6839
# T-Storm                       6546
# Mostly Cloudy / Windy         6297
# Name: ID, dtype: int64

# %%
Weather = weather_conditions.sort_values(ascending=False).head(20).plot(kind='bar')
Weather.set (xlabel ='Weather Condition',
            ylabel='No. of Accidents',
            title='Weather Conditions at Time of Accident')
plt.show()

# %% [markdown]
# # Findings
#
#
# 1. Los Angeles was the city with the highest number of accidents but take note that there was no data from New York (the most      populated city in the US) .
# 2. Less than 5% of cities have more than 1000 yearly accidents
# 3. Over 1100 cities have reported only one accident
# 4. After midnight, little high  no. of accidents occur during 6-8 am (probably the reason behind is people leave for work during    that time period) but the next highest peak of accident is during 3-5 pm (probably the reason behind is people leave for        home after work during that time period)
# 5. No. of accidents during weekends are less as compared to week days but During Weekends the peak of accidents is during
#    12 noon - 6 pm unlike weekdays .
# 6. 4.6 % of accidents found to be very Severe
# 7. Data for 2017 , 2018 seems more balanced, while there were missing data in 2016 and 2020 (2016 start of data collection so      system might not have been fully in place).
# 8. Accidents occurence tend to drop during summer months & pick up by Winter
# 9. Accidents Happend Most frequently on right side of road
# 10. Surprisingly, most accidents happened when the weather was 'fair'. Perhaps weather (bad weather) was not a big contributing      factor to accidents.
